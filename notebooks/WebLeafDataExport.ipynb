# %% [markdown]
# # Creating the files

# %%
import os 
def getmhtml():
    d = "klarna_product_page_dataset_MHTML_50k/test"
    for nation in os.listdir(d):
        if len(nation) > 2 or nation not in ["GB", "US"]:
            continue
        for site in os.listdir(os.path.join(d, nation)):
            if ".DS_Store" in site:
                continue
            for number in os.listdir(os.path.join(d, nation, site)):
                if ".DS_Store" in number:
                    continue
                name = os.path.join(d, nation, site, number, "source.mhtml")
                try:
                    with open(name) as f:
                        yield os.path.join(site, number), f.read(), True
                except FileNotFoundError:
                    with open(name.replace(".mhtml", ".html")) as f:
                        yield  os.path.join(site, number), f.read(), False

# %%
import re 
import quopri

def extract_html_content(text):
    # Define the regex pattern to match content between <!DOCTYPE html> and </html>
    pattern = r'<!DOCTYPE html>.*?</html>'
    
    # Search for the pattern in the text with DOTALL flag to match newlines as well
    match = re.search(pattern, text, re.DOTALL)
    
    # Extract and return the matched content if found
    if match:
        return match.group(0)
    else:
        return None

def decode_quote(s):
    return quopri.decodestring(s)

def extract_html(mhtml):
    pattern = r'boundary="([^"]+)"'
    m = re.search(pattern, mhtml[:10000])
    boundary = m.group(1)
    for chunk in mhtml.split(boundary):
        if "<!DOCTYPE html>" in chunk:
            content = extract_html_content(chunk)
            if content:
                if "quoted-printable" in chunk:
                    content = decode_quote(content)
                return content

# %%
import pickle 

pack = []
BATCH = 100
i = 0
for path, mhtml, htm in getmhtml():
    p = path.replace("/", "-")
    if htm:
        html = extract_html(mhtml)
    else:
        html = mhtml
    if html:
        pack.append(html)
    if len(pack) >= BATCH:
        with open(f'out/webleaf{i}.pkl', "wb") as f:
            pickle.dump(pack, f)
        pack = []
        i += 1

# %% [markdown]
# # Uploading the files

# %%
from google.cloud import storage

def upload_blob(bucket_name, source_file_name, destination_blob_name):
    """Uploads a file to the bucket."""
    # The ID of your GCS bucket
    # bucket_name = "your-bucket-name"
    # The path to your file to upload
    # source_file_name = "local/path/to/file"
    # The ID of your GCS object
    # destination_blob_name = "storage-object-name"

    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)

    # Optional: set a generation-match precondition to avoid potential race conditions
    # and data corruptions. The request to upload is aborted if the object's
    # generation number does not match your precondition. For a destination
    # object that does not yet exist, set the if_generation_match precondition to 0.
    # If the destination object already exists in your bucket, set instead a
    # generation-match precondition using its generation number.
    generation_match_precondition = 0

    blob.upload_from_filename(source_file_name, if_generation_match=generation_match_precondition, content_type='application/octet-stream')

    print(
        f"File {source_file_name} uploaded to {destination_blob_name}."
    )

for f in os.listdir("out"):
    if "webleaf" in f:
        upload_blob("webleaftest", f'out/{f}', f)
    print(f)
# Out:
# .DS_Store
# File out/webleaf0.pkl uploaded to webleaf0.pkl.
# webleaf0.pkl
# File out/webleaf1.pkl uploaded to webleaf1.pkl.
# webleaf1.pkl
# File out/webleaf10.pkl uploaded to webleaf10.pkl.
# webleaf10.pkl
# File out/webleaf11.pkl uploaded to webleaf11.pkl.
# webleaf11.pkl
# File out/webleaf12.pkl uploaded to webleaf12.pkl.
# webleaf12.pkl
# File out/webleaf13.pkl uploaded to webleaf13.pkl.
# webleaf13.pkl
# File out/webleaf14.pkl uploaded to webleaf14.pkl.
# webleaf14.pkl
# File out/webleaf15.pkl uploaded to webleaf15.pkl.
# webleaf15.pkl
# File out/webleaf16.pkl uploaded to webleaf16.pkl.
# webleaf16.pkl
# File out/webleaf17.pkl uploaded to webleaf17.pkl.
# webleaf17.pkl
# File out/webleaf18.pkl uploaded to webleaf18.pkl.
# webleaf18.pkl
# File out/webleaf19.pkl uploaded to webleaf19.pkl.
# webleaf19.pkl
# File out/webleaf2.pkl uploaded to webleaf2.pkl.
# webleaf2.pkl
# File out/webleaf20.pkl uploaded to webleaf20.pkl.
# webleaf20.pkl
# File out/webleaf21.pkl uploaded to webleaf21.pkl.
# webleaf21.pkl
# File out/webleaf22.pkl uploaded to webleaf22.pkl.
# webleaf22.pkl
# File out/webleaf23.pkl uploaded to webleaf23.pkl.
# webleaf23.pkl
# File out/webleaf24.pkl uploaded to webleaf24.pkl.
# webleaf24.pkl
# File out/webleaf25.pkl uploaded to webleaf25.pkl.
# webleaf25.pkl
# File out/webleaf26.pkl uploaded to webleaf26.pkl.
# webleaf26.pkl
# File out/webleaf27.pkl uploaded to webleaf27.pkl.
# webleaf27.pkl
# File out/webleaf28.pkl uploaded to webleaf28.pkl.
# webleaf28.pkl
# File out/webleaf29.pkl uploaded to webleaf29.pkl.
# webleaf29.pkl
# File out/webleaf3.pkl uploaded to webleaf3.pkl.
# webleaf3.pkl
# File out/webleaf30.pkl uploaded to webleaf30.pkl.
# webleaf30.pkl
# File out/webleaf31.pkl uploaded to webleaf31.pkl.
# webleaf31.pkl
# File out/webleaf32.pkl uploaded to webleaf32.pkl.
# webleaf32.pkl
# File out/webleaf33.pkl uploaded to webleaf33.pkl.
# webleaf33.pkl
# File out/webleaf34.pkl uploaded to webleaf34.pkl.
# webleaf34.pkl
# File out/webleaf35.pkl uploaded to webleaf35.pkl.
# webleaf35.pkl
# File out/webleaf36.pkl uploaded to webleaf36.pkl.
# webleaf36.pkl
# File out/webleaf37.pkl uploaded to webleaf37.pkl.
# webleaf37.pkl
# File out/webleaf38.pkl uploaded to webleaf38.pkl.
# webleaf38.pkl
# File out/webleaf39.pkl uploaded to webleaf39.pkl.
# webleaf39.pkl
# File out/webleaf4.pkl uploaded to webleaf4.pkl.
# webleaf4.pkl
# File out/webleaf40.pkl uploaded to webleaf40.pkl.
# webleaf40.pkl
# File out/webleaf41.pkl uploaded to webleaf41.pkl.
# webleaf41.pkl
# File out/webleaf42.pkl uploaded to webleaf42.pkl.
# webleaf42.pkl
# File out/webleaf43.pkl uploaded to webleaf43.pkl.
# webleaf43.pkl
# File out/webleaf44.pkl uploaded to webleaf44.pkl.
# webleaf44.pkl
# File out/webleaf45.pkl uploaded to webleaf45.pkl.
# webleaf45.pkl
# File out/webleaf46.pkl uploaded to webleaf46.pkl.
# webleaf46.pkl
# File out/webleaf47.pkl uploaded to webleaf47.pkl.
# webleaf47.pkl
# File out/webleaf48.pkl uploaded to webleaf48.pkl.
# webleaf48.pkl
# File out/webleaf49.pkl uploaded to webleaf49.pkl.
# webleaf49.pkl
# File out/webleaf5.pkl uploaded to webleaf5.pkl.
# webleaf5.pkl
# File out/webleaf50.pkl uploaded to webleaf50.pkl.
# webleaf50.pkl
# File out/webleaf51.pkl uploaded to webleaf51.pkl.
# webleaf51.pkl
# File out/webleaf52.pkl uploaded to webleaf52.pkl.
# webleaf52.pkl
# File out/webleaf53.pkl uploaded to webleaf53.pkl.
# webleaf53.pkl
# File out/webleaf54.pkl uploaded to webleaf54.pkl.
# webleaf54.pkl
# File out/webleaf55.pkl uploaded to webleaf55.pkl.
# webleaf55.pkl
# File out/webleaf56.pkl uploaded to webleaf56.pkl.
# webleaf56.pkl
# File out/webleaf57.pkl uploaded to webleaf57.pkl.
# webleaf57.pkl
# File out/webleaf58.pkl uploaded to webleaf58.pkl.
# webleaf58.pkl
# File out/webleaf59.pkl uploaded to webleaf59.pkl.
# webleaf59.pkl
# File out/webleaf6.pkl uploaded to webleaf6.pkl.
# webleaf6.pkl
# File out/webleaf60.pkl uploaded to webleaf60.pkl.
# webleaf60.pkl
# File out/webleaf61.pkl uploaded to webleaf61.pkl.
# webleaf61.pkl
# File out/webleaf62.pkl uploaded to webleaf62.pkl.
# webleaf62.pkl
# File out/webleaf63.pkl uploaded to webleaf63.pkl.
# webleaf63.pkl
# File out/webleaf64.pkl uploaded to webleaf64.pkl.
# webleaf64.pkl
# File out/webleaf7.pkl uploaded to webleaf7.pkl.
# webleaf7.pkl
# File out/webleaf8.pkl uploaded to webleaf8.pkl.
# webleaf8.pkl
# File out/webleaf9.pkl uploaded to webleaf9.pkl.
# webleaf9.pkl
